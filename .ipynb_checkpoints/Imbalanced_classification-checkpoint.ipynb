# %% [markdown]
# __Imbalanced Classification__
#
# In many real-world machine learning problems, the target classes are not evenly distributed. This situation is known as imbalanced classification, where one class (the majority class) significantly outnumbers the other class(es) (minority class).
#
# Examples of imbalanced classification include:
#
# Fraud detection (fraud vs. non-fraud transactions)
#
# Disease diagnosis (rare disease vs. healthy patients)
#
# Customer churn prediction (churn vs. non-churn)
#
# Spam detection (spam vs. non-spam)
#
# Traditional evaluation metrics such as accuracy can be misleading in imbalanced datasets, as a model may achieve high accuracy by simply predicting the majority class. Therefore, alternative metrics like precision, recall, F1-score, ROC-AUC, and confusion matrix are more appropriate for evaluating model performance.
#
# In this notebook, we will:
#
# Explore the challenges posed by imbalanced datasets
#
# Analyze class distribution
#
# Apply suitable evaluation metrics
#
# Use techniques such as resampling (oversampling, undersampling) or algorithm-level approaches to improve model performance
#
# The goal is to build models that effectively learn from minority classes while maintaining overall robustness and reliability.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# here 1 means customere who are exited and 0 means customere who are not churned. it is imbalanced because 3/4th of the data are not exited. when we build model, due to imbalanced reason not give good model

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_encoded = pd.get_dummies(
    df,
    columns=["Geography", "Gender"],
    drop_first=True,
    dtype=int
)
df_encoded = df_encoded.drop(columns=["Surname"])

# %%
df_encoded.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0          1    15634602          619   42       2       0.00              1
# 1          2    15647311          608   41       1   83807.86              1
# 2          3    15619304          502   42       8  159660.80              3
# 3          4    15701354          699   39       1       0.00              2
# 4          5    15737888          850   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0          1               1        101348.88       1                  0
# 1          0               1        112542.58       0                  0
# 2          1               0        113931.57       1                  0
# 3          0               0         93826.63       0                  0
# 4          1               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
def model_split(data,weights=None):
       x=data.drop(columns=["Exited"])
       y=data["Exited"]
       x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
       sc= StandardScaler()
       x_train_scaled=sc.fit_transform(x_train)
       x_test_scaled =sc.transform(x_test)
       lr = LogisticRegression(class_weight=weights)
       model=lr.fit(x_train_scaled,y_train)
       y_pred=model.predict(x_test_scaled)
       return (model,x_test_scaled,y_pred,y_test,)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import (
    roc_auc_score,
    precision_score,
    recall_score,
    confusion_matrix,
    accuracy_score,
    roc_curve
)

def classification(y_pred,y_test):
     TP = np.sum((y_pred==1)&(y_test==1))
     TN = np.sum((y_pred==0)&(y_test==0))
     FP = np.sum((y_pred==1)&(y_test==0))
     FN = np.sum((y_pred==0)&(y_test==1))
     PrecisionScore=precision_score(y_test,y_pred)
     RecallScore = recall_score(y_test,y_pred)
     Accuracy = accuracy_score(y_test,y_pred)
    
     return Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore


def curve_(y_test,y_prob,x_test):
     y_prob = model.predict_proba(x_test)[:,1]
     fpr, tpr,threshold=roc_curve(y_test, y_prob)

     plt.figure()
     plt.plot(fpr, tpr)
     plt.plot([0, 1], [0, 1], linestyle='--')
     plt.xlabel("False Positive Rate")
     plt.ylabel("True Positive Rate")
     plt.title("ROC Curve")
     plt.show()

# %%
import pandas as pd

class_data = pd.DataFrame(
    columns=[
        "name", "Accuracy", "TP", "TN", "FP", "FN",
        "PrecisionScore", "RecallScore"
    ]
)

def dataframe(name, Accuracy, TP, TN, FP, FN, PrecisionScore, RecallScore):
    global class_data
    class_data.loc[len(class_data)] = [
        name, Accuracy, TP, TN, FP, FN, PrecisionScore, RecallScore
    ]

# %%
x=df_encoded.drop(columns=["Exited"])
y=df_encoded["Exited"]

# %%
x.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0          1    15634602          619   42       2       0.00              1
# 1          2    15647311          608   41       1   83807.86              1
# 2          3    15619304          502   42       8  159660.80              3
# 3          4    15701354          699   39       1       0.00              2
# 4          5    15737888          850   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Geography_Germany  \
# 0          1               1        101348.88                  0
# 1          0               1        112542.58                  0
# 2          1               0        113931.57                  0
# 3          0               0         93826.63                  0
# 4          1               1         79084.10                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# ...

# %% [markdown]
# <h2>UPSAMPLING</h2>

# %%
from sklearn.utils import resample

# %%
n_rows_maj = (df_encoded["Exited"]==0).sum()
n_min_rows = (df_encoded["Exited"]==1).sum()

# %%
maj_arr=df_encoded.loc[(df_encoded["Exited"]==0),:]
min_arr=df_encoded.loc[(df_encoded["Exited"]==1),:]

# %%
df_upsample = resample(min_arr,
                replace=True,
                n_samples=n_rows_maj,
                random_state=0
                )

# %%
df_upsample
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 3240       3241    15717560          580   50       0  125647.36
# 2629       2630    15711789          768   42       3       0.00
# 8030       8031    15578141          592   38       3       0.00
# 5853       5854    15765300          596   40       5   62389.03
# 3957       3958    15756610          657   38       5  123770.46
# ...         ...         ...          ...  ...     ...        ...
# 4533       4534    15607275          850   39       6  206014.94
# 5658       5659    15814430          747   41       9       0.00
# 9405       9406    15807900          575   36       7       0.00
# 8590       8591    15633194          771   41      10  108309.00
# 9693       9694    15728963          617   51      10  167273.71
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 3240              1          1               0         57541.08       1
# ...

# %%
df_up=pd.concat([df_encoded,df_upsample])

# %%
df_up
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 4533       4534    15607275          850   39       6  206014.94
# 5658       5659    15814430          747   41       9       0.00
# 9405       9406    15807900          575   36       7       0.00
# 8590       8591    15633194          771   41      10  108309.00
# 9693       9694    15728963          617   51      10  167273.71
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1        101348.88       1
# ...

# %%
model,x_test,y_pred,y_test=model_split(df_up)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("Upsample",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data.head()
# Out:
#        name  Accuracy    TP    TN   FP   FN  PrecisionScore  RecallScore
# 0  Upsample  0.715836  1535  1037  584  437        0.724398     0.778398

# %% [markdown]
# <h2>DOWNSAMPLING</h2>

# %%
from sklearn.utils import resample

# %%
n_rows_maj = (df_encoded["Exited"]==0).sum()
n_min_rows = (df_encoded["Exited"]==1).sum()

# %%
maj_arr=df_encoded.loc[(df_encoded["Exited"]==0),:]
min_arr=df_encoded.loc[(df_encoded["Exited"]==1),:]

# %%
df_downsample= resample(maj_arr,
                replace=True,
                n_samples=n_min_rows ,
                random_state=0)

# %%
df_down=pd.concat([df_encoded,df_downsample])

# %%
model,x_test,y_pred,y_test=model_split(df_down)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("Downsample",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data.head()
# Out:
#          name  Accuracy    TP    TN   FP   FN  PrecisionScore  RecallScore
# 0    Upsample  0.715836  1535  1037  584  437        0.724398     0.778398
# 1  Downsample  0.836379    63  1951   41  353        0.605769     0.151442

# %% [markdown]
# <h2>Cluster Centroids Imbalanced Learn</h2>
#    DownSampling
#
#    UpSampling

# %%
from imblearn.under_sampling import ClusterCentroids

# %%
cc = ClusterCentroids()
x=df_encoded.drop(columns=["Exited"])
y=df_encoded["Exited"]
x_sample,y_sample = cc.fit_resample(x,y)

# %%
x_sample.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Age  Tenure        Balance  \
# 0       4038    15723998          651   31       6   96132.116667
# 1       7388    15642567          652   40       3       0.000000
# 2       5852    15619082          603   31       5   81512.155000
# 3       2428    15683528          621   38       5  112605.315000
# 4       3586    15794972          636   40       4       0.000000
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0              1          1               1    173072.503333
# 1              1          0               0     69153.516667
# 2              1          0               1     83189.575000
# 3              1          0               0      8129.692500
# 4              1          0               0    136904.089000
#
#    Geography_Germany  Geography_Spain  Gender_Male
# 0                  0                0            0
# 1                  0                0            0
# ...

# %%
y_sample.value_counts()
# Out:
# Exited
# 0    2037
# 1    2037
# Name: count, dtype: int64

# %%
df_clusterCentroid = pd.merge(x_sample,y_sample,left_index=True,right_index=True)

# %%
df_clusterCentroid.shape
# Out:
# (4074, 14)

# %%
model,x_test,y_pred,y_test=model_split(df_clusterCentroid)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("ClusterCentroid",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data.head()
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699

# %% [markdown]
# UpSampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
Rand_samp = RandomOverSampler(random_state=42)
x_over,y_over = Rand_samp.fit_resample(x,y)

# %%
x_over.shape
# Out:
# (15926, 13)

# %%
y_over.shape
# Out:
# (15926,)

# %%
df_overSample=x_over.merge(y_over,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_overSample)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("Over Sampling",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3    Over Sampling  0.702134  1083  1154  479  470        0.693342
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360

# %% [markdown]
# <h2>SMOTE</h2>
#
# SMOTE (Synthetic Minority Oversampling Technique) is an oversampling method that generates synthetic examples for the minority class. To create a new instance, it identifies the K-nearest neighbors for each minority class sample, randomly selects one of these neighbors, and then generates a new sample by performing a linear interpolation between the original sample and the selected neighbor. This process is repeated until the minority class reaches the desired balance.
#
# SMOTE is widely used because, unlike random oversampling, it reduces the risk of overfitting.
#
# In our implementation, we’ll set ratio='minority' to specifically resample the minority class.

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy='minority')
x_sm,y_sm = sm.fit_resample(x,y)

# %%
x_sm.shape
# Out:
# (15926, 13)

# %%
df_smote=x_sm.merge(y_sm,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_smote)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("SMOTE",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3    Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4            SMOTE  0.784997  1230  1271  362  323        0.772613
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015

# %% [markdown]
# <h2>ADASYN</h2>
#
#
#
# ADASYN (Adaptive Synthetic Sampling Approach) is a sampling method that creates synthetic
# minority class samples based on their distribution. Specifically, it generates more samples in low-density regions of the feature space, where minority examples are harder to learn, and fewer samples in high-density regions, where minority examples are easier to learn.
#
# In other words, ADASYN focuses on adaptively generating synthetic data for minority instances that are more difficult for the model to classify, while producing fewer synthetic samples for those that are easier to learn.

# %%
from imblearn.over_sampling import ADASYN

# %%
ada = ADASYN(sampling_strategy='minority',random_state=42,n_neighbors=5)
x_ada,y_ada = ada.fit_resample(x,y)

# %%
df_adasyn=x_ada.merge(y_ada,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_adasyn)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("ADASYN",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3    Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4            SMOTE  0.784997  1230  1271  362  323        0.772613
# 5           ADASYN  0.787434  1278  1241  369  311        0.775956
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015
# 5     0.804279

# %% [markdown]
# <h2>NEAR MISS</h2>

# %%
from imblearn.under_sampling import NearMiss

# %%
nr = NearMiss(version=1)
x_nr,y_nr = nr.fit_resample(x,y)
df_nr=x_nr.merge(y_nr,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_nr)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("NEAR MISS",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3    Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4            SMOTE  0.784997  1230  1271  362  323        0.772613
# 5           ADASYN  0.787434  1278  1241  369  311        0.775956
# 6        NEAR MISS  0.784049   286   353   90   86        0.760638
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015
# 5     0.804279
# 6     0.768817

# %% [markdown]
# <h2>TOMEK LINKS</h2>

# %%
from imblearn.under_sampling import TomekLinks

# %%
tl = TomekLinks()
x_tl,y_tl = tl.fit_resample(x,y)
df_tl=x_nr.merge(y_tl,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_tl)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("TomekLinks",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)
# Out:
# C:\Users\prasa\OneDrive\Desktop\projects\Imbalanced_class\venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
class_data
# Out:
#               name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0         Upsample  0.715836  1535  1037  584  437        0.724398
# 1       Downsample  0.836379    63  1951   41  353        0.605769
# 2  ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3    Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4            SMOTE  0.784997  1230  1271  362  323        0.772613
# 5           ADASYN  0.787434  1278  1241  369  311        0.775956
# 6        NEAR MISS  0.784049   286   353   90   86        0.760638
# 7       TomekLinks  0.774233     0   631    0  184        0.000000
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015
# 5     0.804279
# 6     0.768817
# 7     0.000000

# %% [markdown]
# <h2>EDITED NEAREST NEIGHBOURS</h2>

# %%
from imblearn.under_sampling import EditedNearestNeighbours

# %%
en = EditedNearestNeighbours()
x_en,y_en = tl.fit_resample(x,y)
df_en=x_en.merge(y_en,right_index=True,left_index=True)

# %%
model,x_test,y_pred,y_test=model_split(df_en)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("EditedNearestNeighbours",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#                       name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0                 Upsample  0.715836  1535  1037  584  437        0.724398
# 1               Downsample  0.836379    63  1951   41  353        0.605769
# 2          ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3            Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4                    SMOTE  0.784997  1230  1271  362  323        0.772613
# 5                   ADASYN  0.787434  1278  1241  369  311        0.775956
# 6                NEAR MISS  0.784049   286   353   90   86        0.760638
# 7               TomekLinks  0.774233     0   631    0  184        0.000000
# 8  EditedNearestNeighbours  0.803976   100  1356   60  295        0.625000
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015
# 5     0.804279
# 6     0.768817
# 7     0.000000
# 8     0.253165

# %% [markdown]
# <h2>COST SENSITIVE MODEL</h2>
#
# Lot of sklearn algrothims have been designed in a way so that they can handle such class imbalance by passing an parameter itself.
#
# You can use class_weight = 'balanced' in such cases. Let's see how to set the parameter in Logistic Regression and Random Forecast Classifier

# %%
unique_numbers = y.nunique()
class0,class1 = y.value_counts()
total_sample = len(y)
print(class0)
# Out:
# 7963

# %%
weight0 = total_sample/(unique_numbers*class0)

# %%
weight1 = total_sample/(unique_numbers*class1)

# %%
weights={0:weight0,1:weight1}

# %%
weights
# Out:
# {0: 0.6279040562602034, 1: 2.454590083456063}

# %%
model,x_test,y_pred,y_test=model_split(df_encoded,weights)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataframe("Cost sensitive model",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
class_data
# Out:
#                       name  Accuracy    TP    TN   FP   FN  PrecisionScore  \
# 0                 Upsample  0.715836  1535  1037  584  437        0.724398
# 1               Downsample  0.836379    63  1951   41  353        0.605769
# 2          ClusterCentroid  0.822086   296   374   69   76        0.810959
# 3            Over Sampling  0.702134  1083  1154  479  470        0.693342
# 4                    SMOTE  0.784997  1230  1271  362  323        0.772613
# 5                   ADASYN  0.787434  1278  1241  369  311        0.775956
# 6                NEAR MISS  0.784049   286   353   90   86        0.760638
# 7               TomekLinks  0.774233     0   631    0  184        0.000000
# 8  EditedNearestNeighbours  0.803976   100  1356   60  295        0.625000
# 9     Cost sensitive model  0.714500   279  1150  457  114        0.379076
#
#    RecallScore
# 0     0.778398
# 1     0.151442
# 2     0.795699
# 3     0.697360
# 4     0.792015
# 5     0.804279
# 6     0.768817
# ...

# %% [markdown]
# __INFERENCE__
#
# Logistic Regression was evaluated using multiple resampling techniques to address class imbalance. The results show that model performance varies significantly depending on the sampling strategy. Methods such as Downsampling and TomekLinks produced high accuracy but extremely low recall, indicating that the model failed to correctly identify the minority class. This makes them unsuitable for imbalance-sensitive problems. Upsampling and Near Miss showed moderate performance but suffered from either higher false positives or false negatives. SMOTE and ADASYN achieved the best balance between precision and recall, with ADASYN providing the highest recall, indicating better detection of minority-class instances. Cluster Centroid also performed well, offering high precision with reasonably strong recall. The cost-sensitive Logistic Regression model improved recall but at the expense of precision, leading to many false alarms. Overall, Logistic Regression combined with SMOTE or ADASYN proved most effective, demonstrating that appropriate resampling is crucial for achieving reliable performance in imbalanced classification problems.

# %% [markdown]
# <h2>USING XGBOO</h2>

# %%
import xgboost
from xgboost import XGBClassifier

# %%
from xgboost import XGBClassifier
def model_split_xg(data,scale_pos_weight=None):
       x=data.drop(columns=["Exited"])
       y=data["Exited"]
       x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
       sc= StandardScaler()
       x_train_scaled=sc.fit_transform(x_train)
       x_test_scaled =sc.transform(x_test)
       xg= XGBClassifier(scale_pos_weight=scale_pos_weight, random_state=0)
       model=xg.fit(x_train_scaled,y_train)
       y_pred=model.predict(x_test_scaled)
       return (model,x_test_scaled,y_pred,y_test)

# %%
data_df = pd.DataFrame(columns=["name","Accuracy","TP","TN","FP","FN","PrecisionScore","RecallScore"])
def dataf(name, Accuracy, TP, TN, FP, FN, PrecisionScore, RecallScore):
    global data_df
    i = len(data_df)
    data_df.loc[i] = [name, Accuracy, TP, TN, FP, FN, PrecisionScore, RecallScore]
    return data_df

# %%
model,x_test,y_pred,y_test=model_split_xg(df_encoded)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataf("xgboost_unweighted",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
data_df
# Out:
#                  name  Accuracy   TP    TN  FP   FN  PrecisionScore  \
# 0  xgboost_unweighted    0.8545  191  1518  89  202        0.682143
#
#    RecallScore
# 0     0.486005

# %%
model,x_test,y_pred,y_test=model_split_xg(df_encoded,scale_pos_weight=3.9)
Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore=classification(y_pred,y_test)
dataf("xgboost_weighted",Accuracy,TP,TN,FP,FN,PrecisionScore,RecallScore)
curve_(y_test, y_pred,x_test)

# %%
data_df
# Out:
#                  name  Accuracy   TP    TN   FP   FN  PrecisionScore  \
# 0  xgboost_unweighted    0.8545  191  1518   89  202        0.682143
# 1    xgboost_weighted    0.8350  256  1414  193  137        0.570156
#
#    RecallScore
# 0     0.486005
# 1     0.651399

# %% [markdown]
# <h2>OneClass SVM</h2>
#
# A One-Class Support Vector Machine (OC-SVM) is an unsupervised learning technique that is trained exclusively on the normal instances, which in this case correspond to class 0 (the majority class). The model learns a decision boundary that encloses these normal data points, enabling it to identify any observations lying outside this boundary as anomalies. These anomalies effectively represent class 1 (the minority class).
#
# Most imbalance-handling algorithms attempt to address class imbalance by linking samples from the minority class and generating synthetic data points along the connections between them. While this approach performs well when the classes are linearly or clearly separable, it often fails to yield performance improvements when such separation does not exist. In such scenarios, anomaly-based methods like One-Class SVM provide a more suitable alternative.

# %%
from sklearn.svm import OneClassSVM

# %%
df_encoded
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1        101348.88       1
# ...

# %%
x=df_encoded.drop(columns=["Exited"])
y=df_encoded["Exited"]
x_churned = x[y==0]
x_outlier = x[y==1]
x_outlier_prop = (len(x_outlier)/len(x))

# %%
x_outlier_prop
# Out:
# 0.2037

# %%
def model_split_sv(data,x_outlier_prop=.2037):
       x=data.drop(columns=["Exited"])
       y=data["Exited"]
    
       x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
       X_train = x_train[y_train==0]
    
       sc= StandardScaler()
       x_train_scaled=sc.fit_transform(X_train)
       x_test_scaled =sc.transform(x_test)
       sv= OneClassSVM(kernel='rbf',nu=x_outlier_prop,gamma=0.000001)
      
       model=sv.fit(x_train_scaled)
       y_pred=model.predict(x_test_scaled)
       y_pred = np.where(y_pred==-1,1,0)
       y_pred_prob=sv.score_samples(x_test_scaled)
       return (model,x_test_scaled,y_pred,y_test)

# %%
def evaluation_matrix(y_pred,y_test):
    TP = sum((y_pred==1) & (y_test==1))
    TN = sum((y_pred==0) & (y_test==0))
    FN = sum((y_pred==0) & (y_test==1))
    FP = sum((y_pred==1) & (y_test==0))
    precisionScore = precision_score(y_test,y_pred)
    RecallScore    = recall_score(y_test,y_pred)
    accuracy       =accuracy_score(y_test,y_pred)
    return TP,TN,FN,FP,precisionScore,RecallScore,accuracy

# %%
dframe = pd.DataFrame(columns = ["TP","TN","FN","FP","PrecisionScore","RecallScore","accuracy"])

# %%
dframe
# Out:
# Empty DataFrame
# Columns: [TP, TN, FN, FP, PrecisionScore, RecallScore, accuracy]
# Index: []

# %%
def make_data_frame(dframe,name,TP,TN,FN,FP,PrecisionScore,RecallScore,accuracy):
    dframe.loc[name] = [TP,TN,FN,FP,PrecisionScore,RecallScore,accuracy]
    return dframe

# %%
model,x_test,y_pred,y_test=model_split_sv(df_encoded)
TP,TN,FN,FP,precisionScore,RecallScore,accuracy=evaluation_matrix(y_pred,y_test)
make_data_frame(dframe,"oneclassSVM",TP,TN,FN,FP,PrecisionScore,RecallScore,accuracy)
# Out:
#                 TP      TN     FN     FP  PrecisionScore  RecallScore  \
# oneclassSVM  158.0  1228.0  235.0  379.0        0.570156     0.402036
#
#              accuracy
# oneclassSVM     0.693
